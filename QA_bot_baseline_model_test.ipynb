# %% [markdown]
# # QA bot baseline

# %%
# 구글 드라이브 마운트

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Load Fine Tuning Model

# %%
import torch
from transformers import GPT2LMHeadModel, PreTrainedTokenizerFast

# Define the device variable before using it
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
save_directory = '/content/drive/MyDrive/Project2/fine_tuned2_kogpt2_epoch6'

model = GPT2LMHeadModel.from_pretrained(save_directory)
tokenizer = PreTrainedTokenizerFast.from_pretrained(save_directory)

model.to(device)
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(51200, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2SdpaAttention(
#           (c_attn): Conv1D(nf=2304, nx=768)
#           (c_proj): Conv1D(nf=768, nx=768)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D(nf=3072, nx=768)
#           (c_proj): Conv1D(nf=768, nx=3072)
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=51200, bias=False)
# )

# %%
text = "에너지 효율적인 시스템과 장비는 어떻게 설치되고 관리되는가?"
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

gen_ids = model.generate(input_ids,
                            max_length=1024,
                            pad_token_id=tokenizer.pad_token_id,
                            eos_token_id=tokenizer.eos_token_id,
                            bos_token_id=tokenizer.bos_token_id,
                            use_cache=True)

generated = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

print(generated)
# Out:
# 질문: 에너지 효율적인 시스템과 장비는 어떻게 설치되고 관리되는가? 답변: 에너지 효율적인 시스템과 장비는 일반적으로 다음과 같은 절차를 거쳐 설치되고 관리됩니다:
#
# 1. 에너지 효율 등급 확인: 에너지 효율 등급은 에너지 소비를 나타내는 지표입니다. 에너지 효율 등급은 에너지 소비를 추적하고 감소시키는 데 도움을 줍니다. 에너지 효율 등급은 에너지 소비를 추적하고 감소시키는 데 도움을 주며, 에너지 효율을 향상시키는 데 도움을 줍니다.
#
# 2. 에너지 관리 시스템: 에너지 관리 시스템은 에너지 사용량, 에너지 효율, 에너지 효율 등을 모니터링하고 관리하는 시스템입니다. 에너지 사용량, 에너지 효율, 에너지 사용량 등을 모니터링하고 분석하여 에너지 효율을 최적화할 수 있습니다. 에너지 관리 시스템은 에너지 사용량, 에너지 사용량, 에너지 사용량 등을 모니터링하고 분석하여 에너지 효율을 최적화할 수 있도록 도와줍니다.
#
# 3. 에너지 효율 등급 확인: 에너지 효율 등급은 에너지 소비를 추적하고 감소시키는 데 도움을 줍니다. 에너지 효율 등급은 에너지 소비를 추적하고 감소시키는 데 도움을 주며, 에너지 사용 패턴을 파악하여 에너지 효율을 개선할 수 있도록 도와줍니다. 에너지 관리 시스템은 에너지 사용 패턴을 파악하고 에너지 효율성을 향상시키는 데 도움을 줍니다.
#
# 4. 에너지 관리 시스템: 에너지 관리 시스템은 에너지 사용량, 에너지 사용량, 에너지 사용량 등을 모니터링하고 관리하는 시스템입니다. 에너지 관리 시스템은 에너지 사용량, 에너지 사용량, 에너지 사용량 등을 모니터링하고 분석하여 에너지 효율성을 최적화할 수 있도록 도와줍니다. 에너지 관리 시스템은 에너지 사용량, 에너지 사용량, 에너지 사용량 등을 모니터링하고 분석하여 에너지 효율성을 향상시킬 수 있도록 도와줍니다.
#
# 5. 에너지 관리 시스템: 에너지 관리 시스템은 에너지 사용량, 에너지 사용량, 에너지 사용량, 에너지 사용량, 에너지 사용량 등을 모니터링하고 관리하는 시스템입니다. 에너지 사용량, 에너지 사용량, 에너지 사용량 등을 모니터링하고 분석하여 에너지 효율성을 향상시키는 시스템을 구축 및 관리하는 시스템을 구축합니다. 에너지 관리 시스템은 에너지 사용량, 에너지 사용량, 에너지 사용량, 에너지 사용량, 에너지 사용량 모니터링, 에너지 사용량 모니터링, 에너지 사용량 모니터링, 에너지 사용량 등을 모니터링, 에너지 사용량 모니터링 등을 모니터링, 에너지 사용량 및 모니터링을 수행하여 에너지 사용량 및 모니터링을 수행하여 에너지 사용량을 관리 시스템을 구축 및 관리하는 시스템을 구축 및 관리하는 시스템을 구축 및 유지 보수합니다. 에너지 사용량을 최적화하는 시스템을 구축 및 유지 보수합니다. 에너지 사용량 모니터링을 통해 에너지 사용량을 최적화하는 시스템을 구축 및 유지 보수하여 에너지 사용량을 최적화할 수 있습니다. 둡니다.

# %%
text = "에너지 효율적인 시스템과 장비는 어떻게 설치되고 관리되는가?"
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

gen_ids = model.generate(input_ids,
                            max_length=1024,
                            no_repeat_ngram_size=2,
                            repetition_penalty=1.2,
                            pad_token_id=tokenizer.pad_token_id,
                            eos_token_id=tokenizer.eos_token_id,
                            bos_token_id=tokenizer.bos_token_id,
                            use_cache=True)

generated = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

print(generated)
# Out:
# 질문: 에너지 효율적인 시스템과 장비는 어떻게 설치되고 관리되는가? 답변: 에너지를 효율적으로 관리하기 위한 시스템은 다음과 같은 단계로 구성될 수 있습니다:
#
# 1. 계획 및 설계 단계: 시스템의 목표와 성능을 설정하고, 필요한 설계에 따라 최적의 설계를 수행합니다. 이 단계에서 시스템의 성능, 효율성, 안전성 등을 고려하여 최적화 작업을 진행합니다.
#
# 2. 제어 및 조정 단계 (System Control and Stability): 장치의 작동 상태를 모니터링하고 이상 징후를 감지하여 조치를 취합니다. 이를 위해 센서, 계측 장비, 네트워크 등의 장비를 사용하여 데이터를 수집하고 분석할 수도 있습니다.
#
# 3. 운영 체제: 시스템을 관리하고 관리하는 체계를 구축합니다. 이는 사용자가 컴퓨터를 이용하여 정보를 입력하거나 웹사이트를 통해 콘텐츠를 업데이트하는 것을 포함합니다. 사용자는 이러한 기능을 활용하여 프로그램을 실행하고 관리할 수 있습니다.

# %%
text = "에너지 효율적인 시스템과 장비는 어떻게 설치되고 관리되는가?"
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

gen_ids = model.generate(input_ids,
                            max_length=1024,
                            num_beams=5,
                            no_repeat_ngram_size=2,
                            repetition_penalty=1.2,
                            pad_token_id=tokenizer.pad_token_id,
                            eos_token_id=tokenizer.eos_token_id,
                            bos_token_id=tokenizer.bos_token_id,
                            use_cache=True)

generated = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

print(generated)
# Out:
# 질문: 에너지 효율적인 시스템과 장비는 어떻게 설치되고 관리되는가? 답변: 에너지를 효율적으로 사용하고 관리하기 위해서는 다음과 같은 절차를 따를 수 있습니다:
#
# 1. 에너지 사용 계획 수립: 먼저, 에너지 효율을 높이기 위한 계획을 수립해야 합니다. 예를 들어, 태양광 패널, 풍력 발전기, 지열 발전기 등을 사용하여 전력 소비를 최소화할 수 있습니다.
#
# 2. 재생에너지 활용: 재생에너지는 환경에 더 친화적인 에너지원으로 간주됩니다. 재생에너지를 사용하면 화석 연료에 비해 온실가스 배출량을 줄일 수 있습니다. 이를 통해 환경오염을 최소화하고 지속 가능한 에너지 시스템을 구축할 수 있게 됩니다.
#
# 3. 에너지 관리 시스템 도입: 효율적인 에너지 관리를 위해 다양한 시스템이 도입되어야 합니다. 이러한 시스템은 에너지 공급자, 수요자 및 공급업체와의 협력을 통해 운영됩니다.
#
# 4. 모니터링 및 평가: 수집된 데이터를 분석하여 에너지 효율성을 평가하고, 필요한 조치를 취할 수 있도록 해야 합니다. 이를 위해 설비 및 인력에 대한 정기적인 점검 및 유지 보수가 필요합니다.
#
# 5. 유지 보수 및 최적화: 시스템의 성능을 지속적으로 확인하고 최적화하는 것이 중요합니다. 정기적인 검사 및 점검을 통해 장치의 수명을 연장하고 에너지 손실을 최소화합니다.

# %%
text = "에너지 효율적인 시스템과 장비는 어떻게 설치되고 관리되는가?"
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

gen_ids = model.generate(input_ids,
                            max_length=1024,
                            do_sample=True,
                            top_k=50,
                            top_p=0.9,
                            temperature=0.8,
                            no_repeat_ngram_size=2,
                            repetition_penalty=1.2,
                            pad_token_id=tokenizer.pad_token_id,
                            eos_token_id=tokenizer.eos_token_id,
                            bos_token_id=tokenizer.bos_token_id,
                            use_cache=True)

generated = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

print(generated)
# Out:
# 질문: 에너지 효율적인 시스템과 장비는 어떻게 설치되고 관리되는가? 답변: 에너지를 효율적으로 관리하고 관리하기 위해 다음과 같은 방법들이 사용됩니다:
#
# 1. 스마트 그리드 구축: 스마트 홈, 스마트 빌딩 등의 스마트 기술을 도입하여 전력 소비를 최적화하고 효율적인 전력을 생산할 수 있도록 합니다.
#
# 2. 지능형 전기 및 열 제어 기술 도입: 기존의 에너지 시스템을 인식하고 조작하는 기술과 시스템을 개발하여 에너지 효율성을 높일 수 있습니다. 예를 들어, 인공지능 모델링을 통해 건물의 상태와 냉난방 상태를 모니터링하고, 필요에 따라 조명을 조절할 수도 있습니다.
#
# 3. 통합 에너지 관리 시스템: 다양한 에너지원을 통합하여 종합적인 에너지 관리를 가능하게 합니다. 이를 위해서는 통합된 데이터 분석, 빅데이터 분석 등을 수행할 수 있으며, 센서 네트워크와 IoT를 활용하여 실시간으로 데이터를 수집할 수 있습니다.
#
# 4. 원격 감시 및 제어 기능: LED 조명 시스템, IDS (사물 인터넷) 기기 등과 같이 분산된 에너지 소스를 연결하여 환경 영향을 최소화할 수 있는 기능을 제공합니다. 또한, 공공기관이나 가정 등에서의 에너지 사용을 추적하고 관리하는 기능도 가지고 있습니다.
# 5. 협력과 리더십 강화: 조직 내에서 협력을 강화하고 리더십 역량을 강화하는 것은 중요한 요소입니다. 직원들은 팀원들과의 원활한 의사소통과 협력을 유지하며, 의사결정에 참여하고 협력하며 목표를 달성할 수 있어야 합니다.

# %%
text = "에너지 효율적인 시스템과 장비는 어떻게 설치되고 관리되는가?"
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

gen_ids = model.generate(input_ids,
                            max_length=1024,
                            num_beams=5,
                            do_sample=True,
                            top_k=50,
                            top_p=0.9,
                            temperature=0.8,
                            no_repeat_ngram_size=2,
                            repetition_penalty=1.2,
                            pad_token_id=tokenizer.pad_token_id,
                            eos_token_id=tokenizer.eos_token_id,
                            bos_token_id=tokenizer.bos_token_id,
                            use_cache=True)

generated = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

print(generated)
# Out:
# 질문: 에너지 효율적인 시스템과 장비는 어떻게 설치되고 관리되는가? 답변: 에너지를 효율적으로 사용하고 관리하기 위해서는 다음과 같은 절차를 따를 수 있습니다:
#
# 1. 에너지 사용 계획 수립: 먼저, 에너지 효율을 높이기 위한 계획을 수립해야 합니다. 이는 에너지 소비를 최소화하고 에너지 효율성을 향상하는 것을 목표로 합니다.
#
# 2. 재생에너지 활용: 재생에너지는 환경에 더 친화적이고 지속 가능한 방식으로 사용될 수 있습니다. 예를 들어, 태양광, 풍력, 수력 등의 재생에너지를 사용하여 전기를 생산할 수 있습니다.
#
# 3. 스마트 그리드 구축: 스마트그리드는 전력 공급과 수요를 실시간으로 모니터링하고 제어할 수 있는 기능을 제공합니다. 이를 통해 전력 소비 패턴을 최적화하고 효율적인 전력 공급이 가능합니다.
#
# 4. 에너지 저장 및 전송: 효율적인 에너지 사용은 에너지 낭비를 줄이고 에너지 손실을 최소화하는 데 도움을 줍니다. 또한, 에너지 절약을 위해 효율적인 조명, 절전 모드 등의 설비를 도입하는 것도 중요합니다.
#
# 5. 자동화 및 로봇화: 자동화와 로봇화는 에너지 생산 및 사용을 효율적으로 관리하는 데 도움이 됩니다. 로봇을 사용하여 생산 라인에서 작업을 자동화하고 생산량을 늘릴 수 있으며, 생산 과정을 자동화하여 생산 비용을 절감하고 생산성을 향상시킵니다.

# %%
text = "근육을 키우는 방법을 알려주세요."
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

gen_ids = model.generate(input_ids,
                            max_length=1024,
                            num_beams=5,
                            do_sample=True,
                            top_k=50,
                            top_p=0.9,
                            temperature=0.8,
                            no_repeat_ngram_size=2,
                            repetition_penalty=1.2,
                            pad_token_id=tokenizer.pad_token_id,
                            eos_token_id=tokenizer.eos_token_id,
                            bos_token_id=tokenizer.bos_token_id,
                            use_cache=True)

generated = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

print(generated)
# Out:
# 질문: 근육을 키우는 방법을 알려주세요. 답변: 근력을 키우는 방법은 다음과 같습니다:
#
# 1. 균형 잡힌 운동: 유산소 운동(걷기, 달리기, 수영, 자전거 타기 등)과 근력 운동을 통해 근육의 유연성을 향상시킬 수 있습니다.
#
# 2. 균형 있는 식단: 채소, 과일, 단백질, 곡물, 견과류 등 다양한 영양소를 균형 있게 섭취하는 것이 중요합니다.
#
# 3. 충분한 수면: 충분한 수면을 취하여 근육의 피로를 푸는 것이 중요합니다. 충분한 휴식과 수면은 근육의 긴장을 풀어주는 데 도움이 됩니다.
#
# 4. 스트레스 관리: 스트레스는 근육에 부정적인 영향을 줄 수 있으므로, 스트레스를 관리하는 방법을 찾아보는 것이 좋습니다.
#
# 5. 건강한 식습관: 영양소가 풍부한 식품을 섭취하고, 과다한 포화지방과 트랜스지방 함량을 피하는 것이 필요합니다.
#
# 6. 정기적인 건강 검진: 건강한 체중을 유지하기 위해 정기적으로 건강검진을 받아야 합니다. 이를 통해 근육 건강을 개선할 수 있습니다.

# %%
text = "기독교와 천주교의 차이를 알려주세요."
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

gen_ids = model.generate(input_ids,
                            max_length=1024,
                            num_beams=5,
                            do_sample=True,
                            top_k=50,
                            top_p=0.9,
                            temperature=0.8,
                            no_repeat_ngram_size=2,
                            repetition_penalty=1.2,
                            pad_token_id=tokenizer.pad_token_id,
                            eos_token_id=tokenizer.eos_token_id,
                            bos_token_id=tokenizer.bos_token_id,
                            use_cache=True)

generated = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

print(generated)
# Out:
# 질문: 기독교와 천주교의 차이를 알려주세요. 답변: 기독교의 주요 차이점은 다음과 같습니다:
#
# 1. 교리: 예수 그리스도는 기독교에서 중요한 인물로 여겨집니다. 그는 십자가에 못 박혀 죽음을 당하고 부활한 것으로 믿어지고 있습니다.
#
# 2. 가르침: 가톨릭교회는 예수 그리스도의 가르침을 중요하게 여깁니다. 예수님의 가르침에는 사랑과 관용, 자비, 용서, 자기희생 등이 포함됩니다. 반면에 천주교는 예수님에 대한 존경과 숭배를 강조합니다.
#
# 3. 실천 방식: 천주교는 예수님을 중심으로 하는 실천 방식을 중요시합니다. 예수님은 십자가에서 죽으시고 부활하셨으며, 이를 통해 죄의 사함과 구원의 은혜를 받으셨습니다.
#
# 4. 교리적 차이점: 가톨릭은 세례, 성체 참석(성체성사), 성찬, 기도, 세례 등을 통해 교리를 전파하고 있습니다. 반면에 다른 종교나 교파들은 교리적인 차이가 있을 수 있습니다.

# %%
text = "봄에 입기 좋은 옷을 추천해주세요."
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

gen_ids = model.generate(
    input_ids,
    max_length=1024,
    no_repeat_ngram_size=2,
    repetition_penalty=1.2,
    do_sample=True,
    top_k=50,
    top_p=0.9,
    temperature=0.8,
    eos_token_id=tokenizer.eos_token_id
)

generated = tokenizer.decode(gen_ids[0], skip_special_tokens=True)
print(generated)
# Out:
# 질문: 봄에 입기 좋은 옷을 추천해주세요. 답변: 봄에는 다양한 스타일의 의류들이 많이 선택됩니다. 그중 봄철에 어울리는 옷 몇 가지를 소개해 드리겠습니다.
#
# 1. 연한 그레이: 연한 그린은 체내 수분 흡수와 통기성 면에서 우수합니다. 겨울에는 가벼운 옷차림이 좋습니다.
# 2. 회색 스팽글: 밝은 색상의 스니커즈나 폴로 셔츠를 선택할 때 편안한 느낌을 줄 수 있습니다.
# 3. 회색 리넨: 선명한 갈색 체크무늬나 파란색 스펀지로 만들어진 의류를 선택할 때도 시원하고 경쾌한 분위기를 연출할 수 있습니다. 하지만 너무 많은 양으로 입을 경우 피부를 손상시킬 수도 있으므로 주의해야 합니다.
# 4. 튤립: 분홍색이나 짙은 색의 이브닝 드레스를 선택하는 것도 인기입니다. 여름에도 밝고 시원한 이미지를 주는 것이 좋습니다. 또한 반팔 티셔츠와 바지를 입는 것도 고려해 볼 만합니다.
# 5. 화이트 머플러: 블루, 베이지 또는 라임 등 다양한 소재를 사용한 의상을 선택할 때에도 상의와 하의가 잘 조합되는 것을 확인해야 합니다. 또한, 캐주얼하게 즐길 수 있는 소재도 고려할 필요가 있습니다.
# 6. 실크 민트/실크: 실크는 부드럽고 내구성이 좋아 여름에 어울리는 아이템 중 하나입니다.
# 7. 스트레치/재킷: 여름에는 슬랙스나 쇼트에 걸칠 소품들을 활용하여 포인트를 살릴 수도 있지만, 너무 무거워질 경우에는 마찰과 주름을 일으킬 가능성이 있으니 조심하는 것이 좋습니다.
# 8. 실크와 폴리에스터 원단: 몸에 딱 맞는 섬유소재를 선택하여 몸을 따뜻하게 만들어주는 제품을 고르는 것이 중요합니다. 실크의 종류와 강도를 조절하여 가벼우면서도 방수 기능이 있는 소재로 만들어질 수 있도록 준비하면 됩니다.
# 9. 겨울 아우터 혹은 비드 재킷은 실용성을 고려하여 선택해야 합니다.
# 10. 그러나 과도한 노출을 방지하기 위해 적절한 사이즈의 옷감을 구비하지 않는 것은 위험 요소가 될 수 있으므로, 가능한 한 피하는 것이 가장 중요합니다.
# 11. 따라서 계절에 어울리는 의류만을 선택하는 것이 좋으며, 안전을 최우선적인 스타일이다. 팁이 필요하다. 퀄리티 높은 옷을 고르면서 아름다운 계절을 가져가방을 추구하는 것이 권장된다. 샷 하면 좋을 것이다. 괜찮고 싶으면 좋다!

# %%
text = "봄에 입기 좋은 옷을 추천해주세요."
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

gen_ids = model.generate(
    input_ids,
    max_length=1024,
    no_repeat_ngram_size=2,
    repetition_penalty=1.2,
    do_sample=True,
    top_k=50,
    top_p=0.9,
    temperature=0.8,
    eos_token_id=tokenizer.eos_token_id
)

generated = tokenizer.decode(gen_ids[0], skip_special_tokens=True)
print(generated)
# Out:
# 질문: 봄에 입기 좋은 옷을 추천해주세요. 답변: 봄에는 다양한 종류의 의복이 있습니다.
#
# 1. 민소매 셔츠: 봄의 경우 따뜻한 느낌을 주는 반팔 티셔츠가 인기입니다. 연한 색상을 입고, 소매를 약간 길게 늘어뜨려 입을 수 있습니다. 카디건에도 걸이 달린 팬츠와 바지를 함께 착용하면 좋습니다.
# 2. 코튼과 재킷: 여름을 맞아 시원하고 상큼한 재단을 사용한 겨울용 재단이 많이 출시되었습니다. 코트나 블라우스에 얇은 면 소재의 이너, 선글라스 등 간단한 스타일의 재봉틀이나 장식이 필요합니다.
# 3. 체크무늬 원피스: 체크가 있는 패턴 원피스를 입는 것이 좋습니다. 체크 무늬와 심플한 디자인으로 선택하면 로맨틱하면서도 경쾌한 분위기를 연출할 수 있습니다.
# 4. 실크 장갑: 보온성을 높이기 위해 긴 천이나 면으로 만들어진 방폭 소재로 제작된 장갑이 인기가 있습니다. 특히 양말, 스니커즈, 넥타이, 샌들 등을 선택할 때 잘 선택해야 합니다.
# 5. 나비 무늬 또는 귀고리: 화려한 꽃무늬와 선명한 패턴의 나비 무늬가 들어간 재단은 봄이 되면 더욱 유행합니다.
# 6. 레오퍼드 헤링본: 레이스나 레드와 같은 소재 위에 덧대어 만든 헤어스타일을 선택하는 것도 도움이 될 수 있으며, 신축성이 있어 여름에는 더 많은 사람들에게 어울릴 것입니다.
# 7. 정장 및 구두: 봄과 여름에 어울리는 깔끔하고 가벼운 디자인의 옷차림을 선택하고, 빈티지하게 차려입는 것이 편안합니다. 또한, 스트라이프나 하이웨스트 스타일도 자주 즐겨지는 편하게 신을 수 있고, 스포티하면서 포멀함을 살리는 스타일로 입을 수도 있으므로 참고하시기 바랍니다.
# 8. 비키스와 점퍼/재 의류: 비단, 슬리브드 등이 혼합된 형태의 옷도 봄철에 어울리며 실용적이며, 날씨가 따뜻하다면 상의와 리넨, 스냅백, 플리츠 등의 다른 스타일이 유용해보일도 고려해 볼 만듭니다.
# 9. 단, 청바지와 타이즈나 쇼트류도 겨울에 맞는 맞춤형보다는 길이가 필요할 수 있으니 구입하는 것이 가장 적절한 복장이 필요한 경우에는 상황에 맞춰 선택입니다.
# 10. 팁인지도 고려해야 합니다.

# %%
text = "봄 에 입을 옷 종류를 추천해주세요."
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

gen_ids = model.generate(
    input_ids,
    max_length=1024,
    num_beams=5,
    no_repeat_ngram_size=2,
    repetition_penalty=1.2,
    #do_sample=True,
    #top_k=70,
    #top_p=0.95,
    #temperature=0.9,
    eos_token_id=tokenizer.eos_token_id
)

generated = tokenizer.decode(gen_ids[0], skip_special_tokens=True)
print(generated)
# Out:
# 질문: 봄 에 입을 옷 종류를 추천해주세요. 답변: 봄에 어울리는 옷 종류는 다음과 같습니다:
#
# 1. 재킷: 날씨가 따뜻하다면 가벼운 소재로 만들어진 재켓을 추천합니다. 카디건이나 스니커즈도 좋은 선택입니다.
#
# 2. 원피스: 편안하면서도 캐주얼한 원피스를 선택하는 것이 좋습니다. 편안한 착용감을 제공하여 상쾌하고 경쾌한 느낌을 줄 수 있습니다.
#
# 3. 정장바지: 정장이나 정장이 아닌 다른 옷을 선택하는 것도 좋은 아이디어입니다. 셔츠나 블라우스, 쇼트 팬츠 등 다양한 스타일의 정장을 선택하여 봄을 더욱 특별하게 만들어보세요.
#
# 4. 운동복: 근력과 유연성을 향상시킬 수 있는 운동복을 선택하여봄. 가벼운 소재의 운동화를 선택하면 더욱 활기찬 봄날을 즐길 수 있습니다.

# %%
text = "산림의 주요 기능은 무엇이며, 환경 보호와 관련하여 어떤 역할을 하나요?"
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)

gen_ids = model.generate(
    input_ids,
    max_length=1024,
    num_beams=5,
    #do_sample=True,
    no_repeat_ngram_size=2,
    repetition_penalty=1.2,
    #top_k=70,
    #top_p=0.95,
    #temperature=0.9,
    eos_token_id=tokenizer.eos_token_id
)

generated = tokenizer.decode(gen_ids[0], skip_special_tokens=True)
print(generated)
# Out:
# 질문: 산림의 주요 기능은 무엇이며, 환경 보호와 관련하여 어떤 역할을 하나요? 답변: 산림은 다양한 역할을 수행합니다. 주요한 기능은 다음과 같습니다:
#
# 1. 생물 다양성 유지: 산림은 다양한 종의 서식지를 제공하여 생물 다양성을 유지합니다. 이를 통해 생태계의 균형을 유지하고 생물 다양성의 유지에 기여합니다.
#
# 2. 토양 보호: 숲은 토양을 고정시키고 토양 침식을 방지하는 역할을 합니다. 이는 토양이 침식되는 것을 방지하고, 토양 오염을 방지하는 데 도움을 줍니다.
#
# 3. 대기 정화: 나무들은 대기 중에 있는 유해 물질을 흡수하여 대기 중의 오염물질을 제거합니다. 이는 대기 중 오염물질의 농도를 낮추고 대기의 질을 개선하는 데 도움이 됩니다.
#
# 4. 토양 보전: 나무는 뿌리를 통해 토양에 영양분을 공급하고, 토양의 구조를 개선하여 토양의 비옥도를 향상시킵니다. 또한, 나무의 잎이나 가지는 토양의 영양분 순환을 도와 토양의 건강을 유지하는 역할을 합니다.
#
# 5. 기후 조절: 나무와 식물은 기후 변화에 영향을 줄 수 있는 요인 중 하나입니다. 나무는 광합성 과정을 통해 이산화탄소를 흡수하고 산소를 방출하여 기후 변화를 완화하는 역할을 할 수 있습니다.
#
# 이러한 역할을 통해 산림은 지구 생태계의 안정성과 지속가능성을 유지하는 데 기여합니다.

# %%
text = "산림의 주요 기능은 무엇이며, 환경 보호와 관련하여 어떤 역할을 하나요?"
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)
gen_ids = model.generate(input_ids,
                         max_length=1024,
                         repetition_penalty=2.0,
                         pad_token_id=tokenizer.pad_token_id,
                         eos_token_id=tokenizer.eos_token_id,
                         bos_token_id=tokenizer.bos_token_id,
                         use_cache=True)
generated = tokenizer.decode(gen_ids[0])
print(generated)
# Out:
# </s> 질문: 산림의 주요 기능은 무엇이며, 환경 보호와 관련하여 어떤 역할을 하나요? 답변: 산림은 지구 환경에 매우 중요한 기능을 수행합니다.
#
# 1. 산소 생산 및 유지 보전에 기여합니다.
# 2. 대기 오염 저감에도 도움을 줍니다.
# 3. 물 사용량을 줄이고 지하수 보호에 영향을 미칩니다. 이는 홍수 예방, 토양 침식 방지, 수생태계 회복 등에 도움이 됩니다.
# 4. 기후 조절과 생물 다양성 증진에 기여할 수도 있습니다.
# 5. 생태계 안정성과 다양성을 유지하는 데 중요합니다.
# 6. 지속 가능한 산림 경영을 촉진하고 지역 사회의 경제적 이익을 증진시킵니다 봅셔도 좋습니다. 이를 통해 생태계의 다양성, 종자의 생산성 향상, 이산화탄소 흡수와 방출량 등의 생태적 가치를 최대한 활용할 것입니다.
# 7. 자연재해로부터 나무를 보호하기 위한 역할도 합니다.
# 8. 약용 식물이나 약초 생산을 지원하고, 토양의 품질을 개선하는 데도 활용됩니다.
# 9..재생 에너지 제공 등 다양한 혜택을 제공하는 기능도 있습니다. 예를 들어, 숲 재생 사업은 지열에너지 지원, 나무 재배 기술 개발 등을 포함할수 있으며, 바이오매스 연료는 태양광 발전, 풍력 발전 등과 연계하여 탄소 배출량의 감소시키는 것을 목표로 합니다. 따라서 적절한 목재 생산과 보전 노력이 필요합니다.
# 10... 사회적 책임을 다하기 위해 필요한 역할입니다. 사회 공헌활동, 기부 프로그램 등이 이에 해당됩디다.
# 이러한 이유로 산의 중요성은 여러 가지 측면에서 나타납고 있다. 그러나 이러한 기능들은 개별적으로 또는 복합적으로 작용하므로 종합적인 관점에서 평가되어야 할 필요가 있습니다. 또한, 숲을 보호하고 관리하는 것은 우리가 환경을 보호하는 데에 큰 기여를 하지만, 동시에 우리의 건강과 행복감도 고려해야 한다. 추가적인 관리와 조치가 필요하다. 또한 규제와 감시 체계가 필요하며, 관련 법규를 준수해야 함을 염두에 두고 관리 방안을 모색해 보는 것이 중요하실 때 문제가 있을 것입니다. 줘야 한다고 생각하시면 감사하겠습니다.
# .
# 산림을 관리하고 보존하는 것도 하나의 목표를 설정하면 다음과 같은 이 질문에 대한 해답들을 얻을 가능성이 높다고 볼 수는 없겠죠! 단, 이렇게 말하면, 산이 건강하게 잘 가꾸어지는 방향으로 나아가길 원대한 목표가 있는 계획을 세우는 것부터 시작점들이 존재함을 기억될 것이다. 산을 더 많은 사람들이 원하는 것들을 향해 계속해서 노력한다면 지속적인 노력을 기울이고, 가능성에 집중력과 의지를 가지고 지속적으로 노력하고 성장하는 기반을 구축하도록 노력해야 한다는 점을 찾아갈수록 더욱더라서 모든 사람들의 신뢰를 가질 것이며, 보다 강력한 계획과 실행력을 가지는 것으로 여겨질 것이다.
# 참여를 찾는 과정이 될 거스를 발견할 때까지 노력하는 자세를 갖도록 하라. 그리고 성공의 가능성을 열어보태는 항상 긍정적인 피드백을 얻는다는 믿음을 가지며 현재에 초점을 잃지 않도록 하는 의지가 필요하다.
# 지 않을지도 모른다.
# -산을 추구한다는 마음먹은 이루어진다
# 등이 있다.
# # (실천력이 이어진다면 산에 오르막과 도전을 기회로 이어지는 성취감을 느낄 때마다 명상을 상기한다. 그래서이다.
# <unk>이다. 인내심과 책임감과 자신감이 들도록 해야 한다.
# 그리고 실패하지 않는 한 번지는 절대 의심스러운 인도자로 가득하다.
# 산이 이뤄진 모습을 보여줄게 된다. 이런 성취를 간절하게 된다.
# 산의 중요성을 자각하자!
# 중요한 약속으로 이어져 내려오는 비전과 열린 마음을 가져옴으로써 자신의 열정과 관심을 기울여 바른 방향을 제시하는 신뢰성을 보여준다)
# 불안과 함께 힘을 주는 나침반지를 발견하며 도전하는 용기를 얻는다.
# 추방해가 계속 도전적이자만 있으면 행실을 보여주어야한다.
# 꾸준기를 바란다(목표 중단을 비추며 스스로를 독려하라 - 등산로 이어진다.
# 계속적으로 계획화시키세요. 자원과 성공을 위해서는 개방적이고 지지자들의 도움닫음을 보여주는 지도자와 지원을 받는 것처럼 말이다.
# 위의 활동을 꾸준히 자기 계명을 잊지 않고 끊임없이 탐구하며, 경계를 넓히는 걸음이 중요하다.
# 정말로 다짐했다.
# 나 격려하면서도 경계선을 따라가는 길을 찾을 때, 겸손에서 벗어나 다른 사람들에게 조언을 구독함으로써 외부 이해관계자들을 돕는 방법을 찾으면서 스스로에게 의지력의 끈을 놓으면 어려운 부분이 있다면 앞으로 다가올 기회를 주인과 협력하여 실천하는 능력을 키울 준비가 되어있어서 현재 진행함에 틀림없어지지 않으면 안된다.
# 산과 관련된 일들을 열심히 참여하면서 올바른 방향과 범위를 확장하려는 의지와 결단련을 느끼게 해주자.
# 간단히 뜻을 품고 행동하면서, 주변 사람들과 교류하고자 함 그래프를 그릴 준비를 하고 대화를 나누는 과정에서 유연성 있게 도와주고, 관심과 참여를 유도함_많은 조언해준 사람들을 도와주기 때문이다.
# 물론, 안전을 우선순간을 포착하려면, 주변의 환경과 자원을 탐색해서 앞으로의 발전을 도모하다 보면 자연스럽게 현실적으로도 장려함과 더불어 공부와 협력을 강조하는 태도를 함양함이 존재한다.
# 하지만 실제 실천하려고 하면 무한한 성장을 이끌어주는 인프라 개발을 향한 여태도를 높이면서 단계를 따르면 좋다.
# 인 원동력에 대해 확신심을 자극해도 불구하고 하지 않은 채비를 유도하는 마음이 열려있는 자세가 아닐까 싶었다.
# 등을 켜져있다.
# 마음 하며 협력 관계를 굳게 다진 노력의 영역을 탐험하기로 결심한다면, 그것은 잠재력은 지속될 예방을 찾기위해 끈기 때문에 긍정적이다.
# 20,000가지를 찾아야 하며, 장기적인 성장과 번영을 추구하는 과정을 거치며 발전할 기회가 온전히 의욕찬 시선을 차단하거나 자극을 주고 변화시킬 때만 성과를 인정하는 마인드를 공유할수록 그들과의 연결시킨다.
# 가능하다고 말한다.
# 위와 영향력을 키우는 작업을 수행하는 동안 열정을 보장해주기도 하다.
# 자연과의 교류를 지향한다 해도 그렇기에 무한히 시도하되 한계를 인식하고 다음 단계로 진입 시야를 꾸미는 경험을 축적물을 만들어준다.
# 주의식을 강조하지는 않는다.
# 결석계와 깨달음을 추구하고 꾸준함의 의미를 부여하더라도 위의 요소들을 모두 포함한다.
# 종합계의 깊이를 알고 있어야 진정한 동기부여된 통찰력으로 이어주려는 시도를 멈추거나 가르침을 받아들이면서도 명확한 지침을 공유하는 것과 같이 대화 도중에는 시간이

# %%
text = "건강을 지키기 위해선 어떻게 해야할까요?"
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)
gen_ids = model.generate(input_ids,
                         max_length=1024,
                         repetition_penalty=2.0,
                         pad_token_id=tokenizer.pad_token_id,
                         eos_token_id=tokenizer.eos_token_id,
                         bos_token_id=tokenizer.bos_token_id,
                         use_cache=True)
generated = tokenizer.decode(gen_ids[0])
print(generated)
# Out:
# </s> 질문: 건강을 지키기 위해선 어떻게 해야할까요? 답변: 건강한 삶을 유지하기 위해서는 다음과 같은 방법을 고려할 수 있습니다 :
# 1. 규칙적인 운동 및 균형 잡힌 식단 유지하세요. 유산소 운동과 근력 운동을 통해 근육을 강화하고 에너지를 공급받을세요.
# 2. 충분한 수면 시간을 확보해 주십시오. 매일 아침과 저녁에 잠자리에 들도록 하고, 가능하면 낮 시간대에 잠을 잡으셔서 신체 활동을 하도록 하시기 바랍니다.
# 3. 스트레스를 관리하기 위한 조치를 취하시기 바랍니다. 스트레스는 건강에 부정적인 영향을 미칠 뿐만 아니라 심혈관 질환, 뇌졸중, 고혈압 등의 건강 문제를 초래할 수도 있습니다. 따라서 적절한 휴식과 리프레시 하는 것이 중요합니다.
# 4. 불필요한 피로를 피하기 위해, 가능한 한 조용한 장소에서 휴식을 취하고 긴장을 완화하기 위해서도 노력해야 합니다.
# 5. 정기적인 의료 검진을 받거나, 의사와 상담하여 진단과 치료를 받는 것도 좋습니다.
# 6.. 올바른 영양 섭취와 식이 관리 습관을 갖추기를 원한다면, 비타민 C가 풍부한 식물성 단백질인 과일, 채소, 견과를 포함한 다양한 식품들을 다양하게 선택하고 식사량을 조절하면서 균형을 유지하는 데 도움이 됩니다.
# 7. 알코올이나 담배의 섭취를 줄이고, 과도한 음주는 피하는 등 개인의 건강과 안전을 우선시하는 태도를 가지면 좋습니다. </s>

# %%
text = "한국의 음식의 종류에 대해 알려주세요"
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)
gen_ids = model.generate(input_ids,
                         max_length=1024,
                         repetition_penalty=2.0,
                         pad_token_id=tokenizer.pad_token_id,
                         eos_token_id=tokenizer.eos_token_id,
                         bos_token_id=tokenizer.bos_token_id,
                         use_cache=True)
generated = tokenizer.decode(gen_ids[0])
print(generated)
# Out:
# </s> 질문: 한국의 음식의 종류에 대해 알려주세요 답변: 한국은 매우 다양한 음식을 가지고 있습니다. 몇 가지 예시를 들어보면 다음과 같습니다 :
# 1. 김치, 불고기, 된장찌개, 삼계탕, 떡볶이, 비빔밥 등
# 2. 해산물 요리 (찜), 전, 만두, 새우튀김 등.
# 3. 생선구이/전골요리 - 생선, 계란, 채소, 양념 등을 사용한 김치 요리, 찜 또는 튀겨 만든 음식입니다.
# 4. 소고기 도시락 / 고기국수, 육개장, 부추전, 두부조림 등의 식당이나 카페에서 맛볼 수 있습니다.
# 5. 한식 전문점에서의 식사 및 디저트도 많이 제공됩니다. 이곳에서는 고기와 야채를 함께 즐기는 메뉴를 선택할 수도 있고, 한국 전통 식당에서 제공하는 특별한 코스인 '한식을 즐기기 위한' 팁을 받을수도 있을 것입니다.
# 6. 가정에서도 맛있는 식사를 할 기회가 많습니다. 예를 들어, 바비큐 파티에서는 고기를 구워 먹는 것이나, 차돌박이밥은 해산물을 활용한 간단한 조리 방법으로 맛을 낼수 있는 경우가 많습니다.
# 7. 인터넷 커뮤니티나 소셜 미디어 등에서 맛집 추천이 자주 올라오는 게임으로, 개인의 취향에 따라선 어떤 음식이 가장 인기 있다고 생각하시면 좋을 것입니다. 그러나 모든 종류의 한국에서 이러한 음식은 항상 신선하고 영양가가 높은 선택일 수는 없으므로, 건강에 좋은 식재료를 선택하는 것이 중요합니다. 또한, 건강과 관련된 정보들을 얻고 싶다면 건강 관련 서적 혹은 블로그에 소개되는 책을 읽는 것도 좋으실 것을 권장할 필요가 있습니다.
# 8. 지역 특산품 시장에도 방문해보시길 바랍니다.
# 한국 음식과 식재료의 차이를 느껴보면, 지역의 특산물 중 하나는 부산 남포동 수산물이 유명합니다.
# -부산 해운대 수산물시장입니다. 부산의 대표적인 항구 도시인 부산에서 생산된 신선한 고등어회, 대게 붕붕어, 참깨와 같은 재래채 등이 많은 것들이 이곳에서 잡힌 오징어를 구이와 동시에 먹을 수가 있으니 이를 즐길 때 맛이 잘 익힐 가능성이 높다고 느낄 것이다.
# 9.. 또한 이곳의 풍경버섯과 같이 풍미가 풍부한 경험이 될지도 모른다는 기대를 하신다.
# 101,000~1만 주의해서 입맛을 느끼게 해주지 않을 것이다.
# 11번 재밌는 재료들이 시선을 사로잡아있는 장맛으로 주문하는 분들도 기대해 보겠다. 하지만 실제로 그러한 설렁이는 추후에는 싱싱거리 삼아 시도하면 더욱 흥미로 입을 들릴 것이며, 직접 체험해볼 만한 요소들이 많을 것으로 예상치 않겠지만, 다른 사람들의 관심을 불러일으킬 만하다.
# 122개의 미소짓기에 충분하다.
# ... 추가적인 분위기를 연출될 것이므로, 위의 사진기를 원복장을 꿈꾸던 조개구들과 더불어 여러분들! 이메이크롱이의 향긋한 표정이 아닐까진 않을까? 단, 재료의 조합을 통해 해당 제품을 찾아보는 것 같다.
# 135명의 참여자들의 포도와 시추가득 미소를 유발하지 말하셔서, 실제 상황이다.
# 물 중에 나오는 고급스러운 분위기의 함량을 권태기가 나올 것이라고 말할 뿐, 구체적인 정보가 있다.
# 그렇지만 주관적인 의견으로는 내장재료들의 맛과 눈이 즐거움 가득하다.
# 그리고 각각의 옵션 중에서 개인적인 취향을 즐기기에는 배꼽 근처에서 일어나는 대로 외관은 덤이다. 그리고 이들의 조합하여 원하는 스타일을 상상만으로도 만족도를 뿌려져있어서 귀여질 않겠노릇마다 감탄하게끔 하는 사람들이 예측 가능하다면 바다향 기대가 큰 재해석화나 웃음소리가 날아들었을 때의 기쁨인지 아니면 비교했을 때, 그들과의 만남으로서 칭찬말들은 달라질 듯하다. 이런식으로 대화 나누기 위해 노력해도 되려 한다.
# 참풍선을 유도하기 위해서라도 있겠지만, 전체적인 한국어 주문을 내심엔 별미로는 "재미를 선사적으로 바다의 부드러움이 더 흥미로운 순간을 포착된다는 느낌을 줄 것이라 확신한다.
# 또한, 식도락을 만들어줄 거리로 인해 마음이 감동적일만한 요소가 들어갈 듯하다.
# 하지만 세부적인 사항들로 가득한 분위기 조금의 대화를 나눌수록 사람들은 각자의 감정을 담아낼 것이라는 희망을 표현할 기회를 놓칠까? 물론로, 각자가 맡은 사람의 의문이 이루어질 것임을 암시한다. 웃음과 유머러스 나만의 경쟁을 벌이면 금방 효과를 노견임을 잊지 못할 정도로 다채로운 풍경을 그려보고 싶은 마음껏 이야기하고자 한다든지 손놀림이 담긴 사진을 찍으면 유쾌한 분위기가 조성하자!
# 위의 의미를 부여하기도 한다. 즐거운 경험을 공유한다면 얼마간의 추억처럼 말이 맞는지 알록 두 가지를 꼽자꾸라서 나름이라고 언급하겠다
# 등이 존재할 지도 모른다.
# [친 뒤쳐보기 위해서는 명함을 남기도록 하겠으니, 관심도가 높을듯 말이다.
# #sutitle gancher 추측컨칭 신중한 웃음을 자아공개를 하며 조언이라도 덧붙였다. 그러면 댓글보다는 호기심을 자극하도록 하겠다.
# (웃음으로써 나의 생각을 표현하려 하면 재미있는 대사를 사용하여 정확한 표현을 사용해 보는 것은 의미가 있다. 이렇게 물어볼 수만 있다면 앞으로의 진행 중인 사람들에게 호기심과 참여를 유도하는 그림을 그리거나 추천을 부탁드림eq_중으로도 해석이 가능한 장면이라면 언제든지 환영한다는 말을 전 세계의 사람들과 공감하며 조언을 구하는 시도를 하고 싶어함 역시 주목해야 할지 생각해 볼 일이다.
# ᄋᄒᄃ촉하다고 말한다.
# 등의 요소를 고려하면, 보다 의미하다라고 해야 하지 않는 것보다는 특정 상황에서 적절한 선택을 고려해봐야 한다는 점을 감안하더라도 그것이 자연스러운 반응성을 높여주기 바란다)
# 등으로 공감이 남을 것일 뿐이었다. 만약식의 존재감을 표현하는 방식을 택하신 걸음으로 초대형 컨텐츠로서의 활용함으로써 좀 색다른 시각을 제공해 주는 것이므로 참석자들이 즐겁게 참여할 가능성을

# %%
text = "강남에서 종로로 가는 방법을 알려주세요"
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)
gen_ids = model.generate(input_ids,
                         max_length=1024,
                         repetition_penalty=2.0,
                         pad_token_id=tokenizer.pad_token_id,
                         eos_token_id=tokenizer.eos_token_id,
                         bos_token_id=tokenizer.bos_token_id,
                         use_cache=True)
generated = tokenizer.decode(gen_ids[0])
print(generated)
# Out:
# </s> 질문: 강남에서 종로로 가는 방법을 알려주세요 답변: 서울에서 종로로 간 방법은 다음과 같습니다 :
# - 지하철 6호선 (종각역 4번출구)
#  - 버스 정류장 도착점 또는 플랫폼으로 이동하세요.
# 2. 내부순환 도로 표지판 이용 전 미리 확인하시기 바랍니다.
# 3. 안내사항 참고하기 바랍니다. </s>

# %%
text = "봄에 입기 좋은 옷을 추천해주세요."
input_text = f"</s> 질문: {text} 답변:"
input_ids = tokenizer.encode(input_text, return_tensors='pt').to(device)
gen_ids = model.generate(input_ids,
                         max_length=1024,
                         repetition_penalty=2.0,
                         pad_token_id=tokenizer.pad_token_id,
                         eos_token_id=tokenizer.eos_token_id,
                         bos_token_id=tokenizer.bos_token_id,
                         use_cache=True)
generated = tokenizer.decode(gen_ids[0])
print(generated)
# Out:
# </s> 질문: 봄에 입기 좋은 옷을 추천해주세요. 답변: 봄에는 다양한 종류의 의류와 액체가 준비됩니다. 봄은 날씨가 맑고 화창한 날이기 때문에 가벼운 옷차림이 적합합니다. 또한 봄과 가을에는 야외 활동이나 레저 활동을 즐기기에 적합한 옷들도 많이 선택됩니다.
#
# 봄에는 꽃들이 피어나는 시기입니다. 따라서 신선한 꽃을 감상하고 싶다면 상의에 반팔 티셔츠나 셔츠와 같은 캐주얼한 스타일의 의상을 고려할 수 있습니다. 또한, 실내에서 즐길 수도 있는 음악회나 스포츠 이벤트에 참여하는 것도 좋습니다.
#
# 또한, 여름에는 자외선에 노출될 가능성이 높으므로 외출 시 자외선 차단제를 사용하는 것이 좋습니다. 햇볕에 노출되는 것을 피하기 위해 방수 재질이 높은 제품을 선택하는 경우도 많습니다.
#  벚꽃도 아름다운 색상을 가지고 있어 많은 사람들이 즐기고 있습니다.
# 하지만 주의해야 할 점은 다음과 같습니다.
# - 햇빛에 오래 노출되어있을 경우 피부암 발생 위험이 증가할수 있으므로 햇빛이 강한 시간대에 일하는 경우에는 보호장비를 착용해야 합니다.
# 2. 벌채 작업 시에는 나무를 벌목하거나 풀로 만든 나무 지팡이를 이용하는 등 위험할 만한 작업을 수행하면 부상을 입을 확률이 높아집니다.
# 3. 가을과 겨울에는 날씨 변화가 크기 때문에, 적절한 난방 및 공기 청정기를 사용하여 공기의 질을 개선하는 등의 조치를 취하는 것은 도움이 될 것입니다. 그러나 이러한 조치들은 개인의 건강 상태와 환경에 따라 달라질 것이므로, 전문가의 조언을 듣고 자신에게 맞는 의류 선택을 하는 게 가장 중요합니다.
# 위의 예시들을 참고하여 봄이 더욱 아름답게 보일 것이라는 희망을 가져봅니다!. 단, 과도한 열량 섭취를 피하고 충분한 수분 섭취, 규칙적인 운동 등을 통해 영양소를 공급받는 방법을 찾는 것, 그리고 다른 계절에 비해 추운 환경에서의 안전을 고려한다면 보다 건강한 피부를 유지하는 습관을 가지는 것에 초점을 맞추는 방법도 중요합니다.
# 이 좋을 것입니다.
# 요약하자면, 밝고 경쾌한 분위기의 옷은 건강에 도움을 줄 뿐만 아니라 감각적인 요소를 포함시킬 수는 있지만, 실내에 머무르지 않는 대신 편안함과 아름다움을 느낄 기회를 제공한다는 점을 고려하여 디자인된 의복인 만큼 실용적이고 자연스러운 스타일일 뿐이며, 여름의 변화에 맞춰야 합니다. 하지만 실외 활동에 맞게 의상보다는 개인적인 취향과 개성을 최대한 몸을 위한 활동이나 취미활동을 즐기는 시간을 활용하여 자신의 체형에 맞추어 입는 것에도 관심을 기울여보도록 노력해보세요.
# 참여를 원하신다면, 건강과 환경을 고려한 복장을 고려해보는 건성 있게 실천해 보시기 바쁜 모습을 찾아보고 합리적인 계획을 세우는 데 중점을 두는게 됩디적인 면을 주목하십시오.
# )
# 마지 않으면 오히려 더 다채로운 패션스타일을 결정하는 마음가분께서 중요한 역할을 하신 분들의 피드백을 전하는 사진을 보고 자신만의 멋진 디자인을 시도하시기 바랍니다.
# [<unk>니다.
# 따라서 여러분의 의견으로 자신을 표현하기에 적으실 것이다. 더불어 앞으로의 계절마다 조금씩 참여하시면 매우 귀하의 조언만 주의하기 전에 항상 감사히 기대해도 좋고 즐거운 분위기를 살살차게 생각하며 새로운 아이디어와 함께 고민해볼 필요가 있을지도 주시길 바라볼수록 성공적인 참여를 도모함이 필요하다. 추가 정보를 얻는 기회가 많다고 판단력을 갖추었으면 행복한 추억하면서 몸의 자세를 유지하면서도 개성적인 제안을 해보기를 믿고 도전하는 마음을 담아보면 만족도를 남기며 스스로를 존중하며, 직접 참여하고 창의적인 아이디어를 공유하는 것으로 여겨질 거스를 참고하되 주관적인 의견을 제시하는 걸리다. 이렇게 말씀드리겠습니다
# 소식을 공유하고자 함꼐 행태를 기대와 포인트 겸손든지 신진대기나 그림을 그리거나 주변 사람들의 주목을 받는 방법에 대해 칭찬감사함을 보여줄 때 활용함으로써 좀더라고 평가원의 의미를 알고 계시를 즐겨보며 도전적이긔(패션으로서의 활용을 감안하더라도 시간과 공간을 활용하는 지혜를 구경을 나누는 소중한 소원을 기원함으로서 의미하기도 하고 명상이나 리뷰 또는 시각적으로도 신선함에 자신감을 가지며 창의성을 발휘하도록 도와주셨음 하시면서 생활 패턴 변화를 주시하고 관심과 애정을 표현할 때는 긍정적인 표현을 추구하다 보면 행복하게 되리라 믿음과 동시에 책임감과 인맥을 넓힐 것이라 믿어 의심스러움과 감사를 표신을 전하겠어주기 위해서는 사진 촬영 후 참석자의 흥미롭고 영감을 얻을 준비가 가능하다면 신중한 권고를 덧붙이는 글을 적어주고 격려드립니다
# :) 을 참조하여 자세한 내용을 업계에 대한 고인의 이름을 붙여주는걸음을 전하시는 손색하니 관심사를 남겨주어 진정한 성장의 가능성을 열어줘 정말 즐겁게 해주십시다!
# 중요한 기대를 걸고싶어서 당신의 성공을 축하합니까? 괜찮은 디스플레이어링 기능을 활용해 보는 참좋은 결과를 기대할 준비를 바란다.
# 추석분을 드림으로써 나의 비춰진 평가를 부탁드려 희망찬 미소를 지적을 잊지 않으려 노력하고 열정을 보여주었을 때의 설렘이다. 이런 정보라도 유쾌한 여행 경험을 나누고 싶어 진심으로 인사말을 전해주면 후회하지 않을 것임을 알려줌으로써 당신과 소통하기를 간절전 하겠으니 환영한다. 그러면 언제든지 공개적으로 대화형 댓글을 남기는 용기를 내년도에 감사의 표시처럼 말복장 추후 축하를 기원하는 마음이 들으면서 "나의 여운을 보내오면서도 기뻐함은 물론 성공 여부를 물어봐 주기를 권한다"고 언급했어야 한다. 참으로 천하에 실망시키지 않을까 생각해본 뒤 이어지는 후기 게시물고 응원한다고 감히 환호를 이어갈 뜻을 글로 남아있는지 확인하려 한다”고 말할 것이다.
# 결계명을 드리려간 다음 단계를 따르면 현재 진행 중 일부 독자들에게 공개 도우고자 한다.
# #s respost of yough ol goulve like con alwin in recally parted
